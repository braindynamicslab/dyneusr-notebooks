# %% [markdown]
# # Example: HCP MegaTrawl

# %%
# for auto-reloading external modules
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import scipy as sp

import networkx as nx
import bct

import dyneusr as ds

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set("paper", "white")

# %matplotlib inline

# %% [markdown]
# ## Load data

# %%
from load_data import load_netmats, Bunch

# load data
data = load_netmats()

# show quick description
print()
print(data.data.shape, data.meta.shape)
print(data.X.shape, data.y.shape)
# Out:
# INFO:load_data:load_netmats(n_subjects=-1, n_runs=-1)
# INFO:load_data:Loading data...
# INFO:load_data:Loading data...
# INFO:root: ** Encoding meta column: Gender
# (1003, 225) (1003, 5)
# (1003, 225) (1003, 5)

# %% [markdown]
# ### Visual inspection of data, meta

# %%
data.data.iloc[:100,:3].plot(figsize=(20,5), subplots=True)
plt.show()

# %%
for col in data.meta.columns:
    data.meta.assign(index=data.meta.index).plot.scatter(
        x='index', y=col, c=col, cmap='Spectral',
        figsize=(20,2), subplots=True
    )
plt.show()

# %% [markdown]
# ## Generate $MAPPER$ graph
#
# Color by:
# - gender, column="Gender"
# - IQ, column="PMAT24_A_CR"

# %%
# define inputs: X=data, y=meta
X = data.data.values
X_inverse = data.data.values

# define y col
#y_col = 'Gender'
y_col = 'PMAT24_A_CR'
y = data.meta[y_col].values

# define y labels (optional)
labels = data.encoders[0][y_col].__dict__.get('classes_')
print('labels:', labels)
# Out:
# labels: None

# %%
import kmapper as km
from sklearn.manifold import TSNE

# init MAPPER
mapper = km.KeplerMapper(verbose=1)

# init MAPPER params
projection = TSNE(perplexity=50, init='pca', random_state=0)
clusterer = km.cluster.KMeans(2)
coverer = km.Cover(10, 0.5)
# Out:
# KeplerMapper()

# %%
# run MAPPER
lens = mapper.fit_transform(X, projection=projection)
graph = mapper.map(lens, X_inverse, clusterer=clusterer, coverer=coverer)
# Out:
# ..Composing projection pipeline of length 1:
# 	Projections: TSNE(angle=0.5, early_exaggeration=12.0, init='pca', learning_rate=200.0,
#    method='barnes_hut', metric='euclidean', min_grad_norm=1e-07,
#    n_components=2, n_iter=1000, n_iter_without_progress=300, perplexity=50,
#    random_state=0, verbose=0)
# 	Distance matrices: False
# 	Scalers: MinMaxScaler(copy=True, feature_range=(0, 1))
# ..Projecting on data shaped (1003, 225)
#
# ..Projecting data using:
# 	TSNE(angle=0.5, early_exaggeration=12.0, init='pca', learning_rate=200.0,
#    method='barnes_hut', metric='euclidean', min_grad_norm=1e-07,
#    n_components=2, n_iter=1000, n_iter_without_progress=300, perplexity=50,
#    random_state=0, verbose=1)
#
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 1003 samples in 0.005s...
# [t-SNE] Computed neighbors for 1003 samples in 0.433s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1003
# [t-SNE] Computed conditional probabilities for sample 1003 / 1003
# [t-SNE] Mean sigma: 11.252407
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.510735
# [t-SNE] KL divergence after 1000 iterations: 1.761605
#
# ..Scaling with: MinMaxScaler(copy=True, feature_range=(0, 1))
#
# Mapping on data shaped (1003, 225) using lens shaped (1003, 2)
#
# Creating 100 hypercubes.
#
# Created 529 edges and 150 nodes in 0:00:00.853058.

# %% [markdown]
# ### Visual inspection of lens

# %%
fig,ax = plt.subplots(1,1,figsize=(10,10))
plt.scatter(*lens.T, c=y, cmap='Spectral')

# %% [markdown]
# ## Fit a `DyNeuGraph` to the $MAPPER$ graph

# %%
# fit DyNeuGraph to MAPPER graph
dG = ds.DyNeuGraph()
dG.fit(graph, y=y, labels=labels)

# show shape of map_ (dimensions: nodes x members)
print()
print('dG.map_:', dG.map_.shape)
print('dG.G_.graph:', dG.G_.graph)
# Out:
# Found 5 unique groups.
#
# dG.map_: (1003, 150)
# dG.G_.graph: {'label': ['n/a', 'μ + -2σ', 'μ + -1σ', 'μ (= 17.02)', 'μ + 1σ'], 'groups': [0, 1, 2, 3, 4]}

# %% [markdown]
# ### Visual inspection of nx.Graph object

# %%
from collections import Counter
node_color = [Counter(y[dG.G_.nodes[n]['members']]).most_common()[0][0] for n in dG.G_]

# plot nx
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ds.tools.networkx_utils.draw_nx(
    dG.G_, lens=lens, pos="inverse", ax=ax, 
    node_color=node_color, cmap='Spectral',
    )

# %% [markdown]
# ## Annotate Graph with images

# %% [markdown]
# ### Plot Temporal Connectivity Matrix (TCM)
#
# ```
# images = ds.visuals.plot_temporal_matrix(dG.tcm_)
# ```

# %%
# plot normalized TCM
tcm_image = ds.visuals.plot_temporal_matrix(
    dG.tcm_, windows=[20], show=True,
    save_as='tcm.png'
)

# assign image to each node
tcm_images = [tcm_image for _ in dG.G_]
# Out:
# /Users/calebgeniesse/src/miniconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Saving figure, save_as: tcm.png

# %%
# annotate dG with images
dG.annotate(image=tcm_images)
# Out:
# Annotating node... NodeID: cube0_cluster1
# Annotating node... NodeID: cube0_cluster0
# Annotating node... NodeID: cube1_cluster0
# Annotating node... NodeID: cube1_cluster1
# Annotating node... NodeID: cube2_cluster1
# Annotating node... NodeID: cube2_cluster0
# Annotating node... NodeID: cube3_cluster1
# Annotating node... NodeID: cube3_cluster0
# Annotating node... NodeID: cube4_cluster0
# Annotating node... NodeID: cube4_cluster1
# Annotating node... NodeID: cube10_cluster1
# Annotating node... NodeID: cube10_cluster0
# Annotating node... NodeID: cube11_cluster1
# Annotating node... NodeID: cube11_cluster0
# Annotating node... NodeID: cube12_cluster0
# Annotating node... NodeID: cube12_cluster1
# Annotating node... NodeID: cube13_cluster1
# Annotating node... NodeID: cube13_cluster0
# Annotating node... NodeID: cube14_cluster0
# Annotating node... NodeID: cube14_cluster1
# Annotating node... NodeID: cube15_cluster1
# Annotating node... NodeID: cube15_cluster0
# Annotating node... NodeID: cube20_cluster1
# Annotating node... NodeID: cube20_cluster0
# Annotating node... NodeID: cube21_cluster0
# Annotating node... NodeID: cube21_cluster1
# Annotating node... NodeID: cube22_cluster0
# Annotating node... NodeID: cube22_cluster1
# Annotating node... NodeID: cube23_cluster0
# Annotating node... NodeID: cube23_cluster1
# Annotating node... NodeID: cube24_cluster0
# Annotating node... NodeID: cube24_cluster1
# Annotating node... NodeID: cube25_cluster0
# Annotating node... NodeID: cube25_cluster1
# Annotating node... NodeID: cube26_cluster0
# Annotating node... NodeID: cube26_cluster1
# Annotating node... NodeID: cube27_cluster0
# Annotating node... NodeID: cube27_cluster1
# Annotating node... NodeID: cube30_cluster1
# Annotating node... NodeID: cube30_cluster0
# Annotating node... NodeID: cube31_cluster1
# Annotating node... NodeID: cube31_cluster0
# Annotating node... NodeID: cube32_cluster0
# Annotating node... NodeID: cube32_cluster1
# Annotating node... NodeID: cube33_cluster1
# Annotating node... NodeID: cube33_cluster0
# Annotating node... NodeID: cube34_cluster0
# Annotating node... NodeID: cube34_cluster1
# Annotating node... NodeID: cube35_cluster0
# Annotating node... NodeID: cube35_cluster1
# Annotating node... NodeID: cube36_cluster0
# Annotating node... NodeID: cube36_cluster1
# Annotating node... NodeID: cube37_cluster1
# Annotating node... NodeID: cube37_cluster0
# Annotating node... NodeID: cube38_cluster1
# Annotating node... NodeID: cube38_cluster0
# Annotating node... NodeID: cube40_cluster0
# Annotating node... NodeID: cube40_cluster1
# Annotating node... NodeID: cube41_cluster0
# Annotating node... NodeID: cube41_cluster1
# Annotating node... NodeID: cube42_cluster1
# Annotating node... NodeID: cube42_cluster0
# Annotating node... NodeID: cube43_cluster0
# Annotating node... NodeID: cube43_cluster1
# Annotating node... NodeID: cube44_cluster0
# Annotating node... NodeID: cube44_cluster1
# Annotating node... NodeID: cube45_cluster0
# Annotating node... NodeID: cube45_cluster1
# Annotating node... NodeID: cube46_cluster0
# Annotating node... NodeID: cube46_cluster1
# Annotating node... NodeID: cube47_cluster0
# Annotating node... NodeID: cube47_cluster1
# Annotating node... NodeID: cube48_cluster0
# Annotating node... NodeID: cube48_cluster1
# Annotating node... NodeID: cube50_cluster1
# Annotating node... NodeID: cube50_cluster0
# Annotating node... NodeID: cube51_cluster1
# Annotating node... NodeID: cube51_cluster0
# Annotating node... NodeID: cube52_cluster0
# Annotating node... NodeID: cube52_cluster1
# Annotating node... NodeID: cube53_cluster1
# Annotating node... NodeID: cube53_cluster0
# Annotating node... NodeID: cube54_cluster1
# Annotating node... NodeID: cube54_cluster0
# Annotating node... NodeID: cube55_cluster1
# Annotating node... NodeID: cube55_cluster0
# Annotating node... NodeID: cube56_cluster0
# Annotating node... NodeID: cube56_cluster1
# Annotating node... NodeID: cube57_cluster0
# Annotating node... NodeID: cube57_cluster1
# Annotating node... NodeID: cube58_cluster1
# Annotating node... NodeID: cube58_cluster0
# Annotating node... NodeID: cube61_cluster1
# Annotating node... NodeID: cube61_cluster0
# Annotating node... NodeID: cube62_cluster1
# Annotating node... NodeID: cube62_cluster0
# Annotating node... NodeID: cube63_cluster0
# Annotating node... NodeID: cube63_cluster1
# Annotating node... NodeID: cube64_cluster1
# Annotating node... NodeID: cube64_cluster0
# Annotating node... NodeID: cube65_cluster1
# Annotating node... NodeID: cube65_cluster0
# Annotating node... NodeID: cube66_cluster0
# Annotating node... NodeID: cube66_cluster1
# Annotating node... NodeID: cube67_cluster0
# Annotating node... NodeID: cube67_cluster1
# Annotating node... NodeID: cube68_cluster0
# Annotating node... NodeID: cube68_cluster1
# Annotating node... NodeID: cube69_cluster1
# Annotating node... NodeID: cube69_cluster0
# Annotating node... NodeID: cube72_cluster1
# Annotating node... NodeID: cube72_cluster0
# Annotating node... NodeID: cube73_cluster1
# Annotating node... NodeID: cube73_cluster0
# Annotating node... NodeID: cube74_cluster0
# Annotating node... NodeID: cube74_cluster1
# Annotating node... NodeID: cube75_cluster1
# Annotating node... NodeID: cube75_cluster0
# Annotating node... NodeID: cube76_cluster0
# Annotating node... NodeID: cube76_cluster1
# Annotating node... NodeID: cube77_cluster1
# Annotating node... NodeID: cube77_cluster0
# Annotating node... NodeID: cube78_cluster1
# Annotating node... NodeID: cube78_cluster0
# Annotating node... NodeID: cube79_cluster0
# Annotating node... NodeID: cube79_cluster1
# Annotating node... NodeID: cube83_cluster1
# Annotating node... NodeID: cube83_cluster0
# Annotating node... NodeID: cube84_cluster0
# Annotating node... NodeID: cube84_cluster1
# Annotating node... NodeID: cube85_cluster0
# Annotating node... NodeID: cube85_cluster1
# Annotating node... NodeID: cube86_cluster1
# Annotating node... NodeID: cube86_cluster0
# Annotating node... NodeID: cube87_cluster1
# Annotating node... NodeID: cube87_cluster0
# Annotating node... NodeID: cube88_cluster0
# Annotating node... NodeID: cube88_cluster1
# Annotating node... NodeID: cube89_cluster1
# Annotating node... NodeID: cube89_cluster0
# Annotating node... NodeID: cube93_cluster1
# Annotating node... NodeID: cube93_cluster0
# Annotating node... NodeID: cube95_cluster1
# Annotating node... NodeID: cube95_cluster0
# Annotating node... NodeID: cube96_cluster0
# Annotating node... NodeID: cube96_cluster1
# Annotating node... NodeID: cube97_cluster1
# Annotating node... NodeID: cube97_cluster0
# Annotating node... NodeID: cube98_cluster1
# Annotating node... NodeID: cube98_cluster0
# Annotating Graph...
# DyNeuGraph()

# %% [markdown]
# ## Visualize `DyNeuGraph`

# %%
# %%script bash --bg
#
# python3 -m http.server 8882
# Out:
# Starting job # 4 in a separate thread.

# %%
dG.visualize(PORT=8882)
# Out:
# 0
# 1
# 2
# 3
# 4
# [Force Graph] http://localhost:8882/index.html
# DyNeuGraph()
